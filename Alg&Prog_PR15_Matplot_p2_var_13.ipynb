# %% [markdown]
# # Визуальный анализ данных. Построение сложных графиков

# %% [markdown]
# # Вариант 13

# %% [markdown]
# **Задача прогнозирования урожайности** — ключевое направление в точном земледелии для оптимизации ресурсов и повышения продуктивности
#
# Будем работать с датасетом `crop_yield`.
#
# <b>Генерация данных: </b>
# 1. Файл `crop_yield.csv` должен содержать данные о полях и урожаях.
# 2. Сгенерируйте данные самостоятельно либо с помощью НС, либо используя Pandas
# 3. Обязательные поля:
# - ```field_area_ha``` - площадь поля, га (вещественное)
# - ```fertilizer_kg_per_ha``` - внесение удобрений, кг/га (вещественное)
# - ```rainfall_mm``` - количество осадков за сезон, мм (вещественное)
# - ```soil_ph``` - кислотность почвы (вещественное, 4.0–9.0)
# - ```num_pest_treatments``` - количество обработок от вредителей (натуральное)
# - ```is_irrigated``` - наличие орошения (бинарное: 0/1)
# - ```high_yield``` - урожайность выше медианы по региону (бинарное: 0/1)
#
# 4. В датасете ≥10_000 строк, обязательны числовые, текстовые и временные поля.
# 5. Данные должны содержать пропуски и дубликаты.
# 6. Сохраните в `crop_yield.csv`.

# %% [markdown]
# ### Исследуем данные о полях и научимся отвечать на вопросы.

# %% [markdown]
# ## Задача 1

# %% [markdown]
# Импортируйте необходимые библиотеки

# %%
# Ваш код здесь

# %% [markdown]
# Считайте файл ```crop_yield.csv```

# %%
# Ваш код здесь

# %% [markdown]
# Посмотрите первые пять строк:

# %%
# Ваш код здесь

# %% [markdown]
# Выведите список названий столбцов:

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Определите долю полей с высокой урожайностью (колонка ```high_yield```):

# %%
# Ваш код здесь

# %% [markdown]
# ```0.42156```

# %% [markdown]
# ## Задача 3

# %% [markdown]
# Определите количество полей, у которых внесение удобрений ```fertilizer_kg_per_ha``` выше среднего:

# %%
# Ваш код здесь

# %% [markdown]
# ```5134```

# %% [markdown]
# ## Задача 4

# %% [markdown]
# Вычислите, сколько полей с количеством осадков выше 500 мм (```rainfall_mm > 500```) имеют внесение удобрений выше среднего:

# %%
# Ваш код здесь

# %% [markdown]
# ```2789```

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Постройте гистограмму распределения признака `num_pest_treatments` для полей с высокой урожайностью (`high_yield = 1`).
#
# Подпишите оси, добавьте сетку, дайте название:

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 6

# %% [markdown]
# Постройте гистограмму распределения `soil_ph` всех полей. Используйте `plot.hist()`, параметр `bins`. Постройте два графика с `bins=10` и `bins=30` на одной плоскости.
#
# Подпишите оси, добавьте сетку, названия. Завершите `plt.show()`.

# %%
# Ваш код здесь
